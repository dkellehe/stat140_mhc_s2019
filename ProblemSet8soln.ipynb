# %% [markdown]
# ## <span style="color:darkblue"> Problem Set 8

# %% [markdown]
# **Problem set policies:** Please provide concise, clear answers for each question. Note that only writing the result of a calculation (e.g., "SD = 3.3") without explanation is not sufficient. For problems involving `R`, include the code in your solution, along with any plots.
#
# *You are encouraged to discuss problems with other students (and, of course, with the course head and the TAs), but you must write your final answer in your own words. Solutions prepared "in committee" are not acceptable. If you do collaborate with classmates on a problem, please list your collaborators on your solution.*

# %% [markdown]
# ### Probelm 1
#
# Suppose that you are interested in determining whether exposure to the organochloride DDT, which has been used extensively as an insecticide for many years, is associated with breast cancer in women. As part of a study that investigated this issue, blood was drawn from a sample of women diagnosed with breast cancer over a six-year period and a sample of healthy control subjects matched to the cancer patients on age, menopausal status, and date of blood donation. Each woman’s blood level of DDE (an important byproduct of DDT in the human body) was measured, and the diﬀerence in levels for each patient and her matched control calculated. A sample of $171$ such diﬀerences has mean $\overline d = 2.7$ ng/mL and standard deviation $sd = 15.9$ ng/mL. Diﬀerences were calculated as $DDE_{cancer} −DDE_{control}$. Test the null hypothesis that the mean blood levels of DDE are identical for women with breast cancer and for healthy control subjects. What do you conclude?

# %%
# this is independent data, so we need to treat it as such.
dbar=2.7
SE=15.9/sqrt(171)
T = (dbar-0)/SE
"The p value is"
2*pt(-T,170)

# %% [markdown]
# Answer: This means that the $p=2.77\%<5\%$ which means that we would conclude that this is strong evidence for DDT causing cancer.

# %% [markdown]
# ### Problem 2 (7.4 Identify relationships, Part II.)
#
# For each of the six plots, identify the strength of the relationship (e.g. weak, moderate, or strong) in the data and whether fitting a linear model would be reasonable.
#
# ![Screen%20Shot%202019-03-28%20at%208.21.43%20AM.png](attachment:Screen%20Shot%202019-03-28%20at%208.21.43%20AM.png)

# %% [markdown]
# Answer:
# a) Strong relationship but does not follow a linear trend
#
# b) Strong relationship but does not follow a linear trend
#
# c) Strong relationship and good linear relationship
#
# d) Weak but good linear
#
# e) weak but good linear
#
# f) medium but good linear

# %% [markdown]
# ### Problem 3 (7.6 Husbands and wives, Part I.)
#
# The Great Britain Office of Population Census and Surveys once collected data on a random sample of 170 married couples in Britain, recording the age (in years) and heights (converted here to inches) of the husbands and wives.16 The scatterplot on the left shows the wife’s age plotted against her husband’s age, and the plot on the right shows wife’s height plotted against husband’s height.
#
# ![Screen%20Shot%202019-03-28%20at%208.26.18%20AM.png](attachment:Screen%20Shot%202019-03-28%20at%208.26.18%20AM.png)

# %% [markdown]
# a)  Describe the relationship between husbands’ and wives’ ages. (interpret in the context of the data)

# %% [markdown]
# Answer: There is a close linear relationship between the two... this means that the older the husband the older the wife, and vice versa.

# %% [markdown]
# b) Describe the relationship between husbands’ and wives’ heights. (interpret in the context of the data)

# %% [markdown]
# Answer: There is little to no relationship, i.e. the a person's height does not effect the height of their partner.

# %% [markdown]
# ### Problem 4 (7.8 Match the correlation, Part II.)
#
# Match the calculated correlations to the corresponding scatterplot.
# (a) r = 0.49 (b) r = −0.48 (c) r = −0.03 (d) r = −0.85
#
# ![Screen%20Shot%202019-03-28%20at%208.32.41%20AM.png](attachment:Screen%20Shot%202019-03-28%20at%208.32.41%20AM.png)

# %% [markdown]
# Answer: a) 2, b) 4, c) 3, d) 1
